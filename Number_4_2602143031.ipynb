# %%
# Clone repository deep-speaker
# !git clone https://github.com/philipperemy/deep-speaker.git
# %cd deep-speaker

# Install dependencies
# !pip install -r requirements.txt
# !pip install librosa soundfile scipy scikit-learn gdown
# Out:
# Cloning into 'deep-speaker'...
# remote: Enumerating objects: 2114, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 2114 (delta 113), reused 187 (delta 104), pack-reused 1887 (from 1)
# Receiving objects: 100% (2114/2114), 81.51 MiB | 47.15 MiB/s, done.
# Resolving deltas: 100% (1102/1102), done.
# /content/deep-speaker
# Requirement already satisfied: natsort>=7.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: librosa>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: dill>=0.3.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.3.8)
# Collecting python_speech_features>=0.6 (from -r requirements.txt (line 4))
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.45.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: click>=7.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (8.3.1)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (2.19.0)
# Requirement already satisfied: Keras>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (2.0.2)
# Requirement already satisfied: numba>=0.48 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.60.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.7.2->-r requirements.txt (line 2)) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.3->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.3->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.3->-r requirements.txt (line 7)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->-r requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->-r requirements.txt (line 8)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->-r requirements.txt (line 8)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->-r requirements.txt (line 8)) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->-r requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->-r requirements.txt (line 8)) (3.3.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (2.19.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->-r requirements.txt (line 9)) (0.5.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from Keras>=2.3.1->-r requirements.txt (line 10)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from Keras>=2.3.1->-r requirements.txt (line 10)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from Keras>=2.3.1->-r requirements.txt (line 10)) (0.18.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.48->-r requirements.txt (line 12)) (0.43.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 9)) (0.45.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.7.2->-r requirements.txt (line 2)) (4.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 9)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 9)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 9)) (2026.1.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa>=0.7.2->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa>=0.7.2->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 9)) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 9)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 9)) (3.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->Keras>=2.3.1->-r requirements.txt (line 10)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->Keras>=2.3.1->-r requirements.txt (line 10)) (2.19.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.7.2->-r requirements.txt (line 2)) (2.23)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->Keras>=2.3.1->-r requirements.txt (line 10)) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 9)) (3.0.3)
# Building wheels for collected packages: python_speech_features
#   Building wheel for python_speech_features (setup.py) ... done
#   Created wheel for python_speech_features: filename=python_speech_features-0.6-py3-none-any.whl size=5868 sha256=da93bc46d89be6e32ea36b956100740a517deed3775145a9ffa7a54a45edbbe0
#   Stored in directory: /root/.cache/pip/wheels/60/90/3c/4b5996a95d363fa14525597a19146a940bec467b44b2a14580
# Successfully built python_speech_features
# Installing collected packages: python_speech_features
# Successfully installed python_speech_features-0.6
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from librosa) (2.0.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.5.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.1.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !sed -i 's/regularizers.l2(l=/regularizers.l2(l2=/g' deep_speaker/conv_models.py

# %%
# !pip install --upgrade ml_dtypes
# Out:
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (0.5.4)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from ml_dtypes) (2.0.2)

# %%
import sys
import os
import random
import numpy as np
import pandas as pd
import gdown
from scipy.spatial.distance import cosine
from IPython.display import Audio, display

# Import dari deep_speaker
from deep_speaker.audio import read_mfcc
from deep_speaker.batcher import sample_from_mfcc
from deep_speaker.constants import SAMPLE_RATE, NUM_FRAMES
from deep_speaker.conv_models import DeepSpeakerModel

print(f"SAMPLE_RATE: {SAMPLE_RATE} Hz")
print(f"NUM_FRAMES: {NUM_FRAMES} frames")
# Out:
# SAMPLE_RATE: 16000 Hz
# NUM_FRAMES: 160 frames

# %%
#Download dan Load Model
file_id = '1F9NvdrarWZNktdX9KlRYWWHDwRkip_aP'
output_filename = 'ResCNN_triplet_training_checkpoint_265.h5'

if not os.path.exists(output_filename):
    gdown.download(id=file_id, output=output_filename, quiet=False)

model = DeepSpeakerModel()
model.m.load_weights(output_filename, by_name=True)
print("Model loaded")
# Out:
# Model loaded

# %%
def get_voice_embedding(filename):
    """Ekstrak embedding 512-dimensional dari file audio."""
    mfcc = read_mfcc(filename, SAMPLE_RATE)
    mfcc_input = sample_from_mfcc(mfcc, NUM_FRAMES)
    network_input = np.expand_dims(mfcc_input, axis=0)
    embedding = model.m.predict(network_input, verbose=0)
    return embedding.flatten()

def verify_speaker(file1, file2, threshold=0.50):
    """Verifikasi apakah dua file audio berasal dari speaker yang sama."""
    emb1 = get_voice_embedding(file1)
    emb2 = get_voice_embedding(file2)
    similarity = 1 - cosine(emb1, emb2)
    conclusion = "Speaker SAMA" if similarity >= threshold else "Speaker BERBEDA"
    return similarity, conclusion

# %%
# Tampilkan dan mainkan audio samples
print("Samples Preview:")
print("=" * 50)

for name, path in audio_samples.items():
    if os.path.exists(path):
        print(f"\n{name}:")
        display(Audio(path))
# Out:
# Samples Preview:
# ==================================================
#
# A1 (Philippe):
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# A2 (Philippe):
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# B1 (Unknown):
#                 <audio  controls="controls" >
#                     <source src="data:audio/flac;base64,..." type="audio/flac" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Cell 7: Pengujian Speaker Recognition
# Audio samples dari repository
audio_samples = {
    "A1 (Philippe)": 'samples/PhilippeRemy/PhilippeRemy_003.wav',
    "A2 (Philippe)": 'samples/PhilippeRemy/PhilippeRemy_004.wav',
    "B1 (Unknown)": 'samples/1255-90413-0001.flac'
}

# Pasangan pengujian
tests = [
    ("Test: Speaker Sama", audio_samples["A1 (Philippe)"], audio_samples["A2 (Philippe)"]),
    ("Test: Speaker Berbeda", audio_samples["A1 (Philippe)"], audio_samples["B1 (Unknown)"])
]

THRESHOLD = 0.50

print("=" * 70)
print("HASIL PERBANDINGAN COSINE SIMILARITY")
print("=" * 70)
print(f"\nThreshold: {THRESHOLD}")
print("Alasan: Threshold 0.5 dipilih karena berada di titik tengah antara")
print("        typical same-speaker (~0.7-0.9) dan different-speaker (~0.1-0.3)")
print("        sehingga memberikan margin keamanan yang cukup.")
print("\n" + "-" * 70)
print(f"{'Pasangan Audio':<30} | {'Similarity':<12} | {'Kesimpulan'}")
print("-" * 70)

for label, file1, file2 in tests:
    score, result = verify_speaker(file1, file2, THRESHOLD)
    print(f"{label:<30} | {score:<12.4f} | {result}")

print("=" * 70)
# Out:
# ======================================================================
# HASIL PERBANDINGAN COSINE SIMILARITY
# ======================================================================
#
# Threshold: 0.5
# Alasan: Threshold 0.5 dipilih karena berada di titik tengah antara
#         typical same-speaker (~0.7-0.9) dan different-speaker (~0.1-0.3)
#         sehingga memberikan margin keamanan yang cukup.
#
# ----------------------------------------------------------------------
# Pasangan Audio                 | Similarity   | Kesimpulan
# ----------------------------------------------------------------------
# Test: Speaker Sama             | 0.8608       | Speaker SAMA
# Test: Speaker Berbeda          | 0.0087       | Speaker BERBEDA
# ======================================================================
